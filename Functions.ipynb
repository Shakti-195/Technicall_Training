# %%
#1 Write a function that prints "Hello,World!".
def greet():
    print("Hello,welcome to python")

greet()
# Out:
# Hello,welcome to python

# %%
#2 Write a function that takes a name as input and prints "Hello,<name>
def greet (name):
    print("Hello",name)


greet("Bob")
# Out:
# Hello Bob

# %%
#3 Write a function that takes two numbers and prints their sum. 
def add (a,b):
    return a + b
result = add(5,3)
print (result)
# Out:
# 8

# %%
#4 Write a function that returns the square of a number. 
def square(num):
    return num * num 
result = square (4)
print(result)
# Out:
# 16

# %%
# 5 Write a function to check if a number is even or odd. 
def even_or_odd(num):
    if num % 2 == 0:
        print("Even")
    else:
        print("odd")

even_or_odd(7)
# Out:
# odd

# %%
#6 Write a function that takes two numbers and returns their maximum. 
def maximum (a,b):
    return a if a > b else b

print (maximum (10,20))
# Out:
# 20

# %%
#7 Write a function that takes a list of numbers and returns their average.
def average (numbers):
    return sum (numbers)/ len (numbers)

nums = [10,20,30,40]
print (average(nums))
# Out:
# 25.0

# %%
# 8 Write a function that counts vowels in a string.
def count_vowels(text):
    vowels = "aeiouAEIOU"
    count = 0
    for ch in text:
        if ch in vowels:
            count += 1
    return count

print(count_vowels("Python Programming"))
# Out:
# 4

# %%
# 9 Write a function that calculates factorial of a number (using loop)
def factorial(n):
    fact = 1
    for i in range (1,n+1):
        fact *=i
    return fact 
print(factorial(5))
# Out:
# 120

# %%
# 10 Write a function to check if a string is a palindrome.  
def is_palindrome(text):
    return text == text[::-1]

print(is_palindrome("madam"))
# Out:
# True

# %%
# 11  Write a function that calculates simple interest (default rate = 5%).
def simple_interest (p,t,r = 5):
    return (p*r*t)/100

print(simple_interest(1000,2))
# Out:
# 100.0

# %%
# 12  Write a function that takes a name and age and prints them (use keyword arguments). 
def show_details(name,age):
    print("name",name)
    print("age",age)

show_details(age = 20,name = "Aman")
# Out:
# name Aman
# age 20

# %%
# 13 Write a recursive function to calculate factorial. 
def factorial(n):
    if n == 0 or n == 1:
        return 1 
    return n * factorial(n-1)
print(factorial(5))
# Out:
# 120

# %%
# 14 Write a recursive function to print Fibonacci series up to n terms. 
def fibonacci(n):
    if n < 1:
        return n
    return fibonacci(n-1) +fibonacci(n-2)
n=6
for i in range (n):
    print(fibonacci(i),end = " ")
# Out:
# 0 -1 -1 -2 -3 -5

# %%
# 15  Write a function that takes a list of numbers and returns the largest element.
def largest_element(numbers):
    return max (numbers)

print(largest_element([10,45,23,89,5]))
# Out:
# 89

# %%
# 16 Write a function that takes a dictionary and prints all key-value pairs.
def print_dict(data):
    for key, value in data.items():
        print(key, ":", value)

info = {"name": "Rahul", "age": 21, "city": "Delhi"}
print_dict(info)
# Out:
# name : Rahul
# age : 21
# city : Delhi

# %%
# 17  Write a function that takes a set and returns its length. 
def set_length(s):
    return len(s)

print(set_length({1, 2, 3, 4, 5}))
# Out:
# 5

# %%
# 18  Write a function that takes a list of dictionaries (students with marks) and returns the 
# topper’s name.

def topper(students):
    top = max(students, key=lambda x: x["marks"])
    return top["name"]

students = [
    {"name": "Aman", "marks": 85},
    {"name": "Riya", "marks": 92},
    {"name": "Karan", "marks": 88}
]

print(topper(students))
# Out:
# Riya
